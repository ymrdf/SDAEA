# %%
from godot_rl.core.godot_env import GodotEnv
from dataclasses import dataclass
from collections import deque

from torch.distributions.categorical import Categorical

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# Device selection: CUDA > MPS (Apple Silicon) > CPU
if torch.cuda.is_available():
    device = torch.device("cuda:0")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"Using device: {device}")

# Create GodotEnv
env = GodotEnv(show_window=True)

# Get action space info
# GodotEnv returns list of action dicts per agent
# Each agent has: accelerate_forward (3), accelerate_sideways (3), turn (3), shoot (2)
print(f"Environment: GodotEnv")
print(f"Action space: {env.action_space}")
print(f"Observation space: {env.observation_space}")
print(f"envs:{env.num_envs}")
# Out:
# Using device: mps
# No game binary has been provided, please press PLAY in the Godot editor
# waiting for remote GODOT connection on port 11008
# connection established
# action space [{'accelerate_forward': {'size': 3, 'action_type': 'discrete'}, 'accelerate_sideways': {'size': 3, 'action_type': 'discrete'}, 'turn': {'size': 3, 'action_type': 'discrete'}, 'shoot': {'size': 2, 'action_type': 'discrete'}}, {'accelerate_forward': {'size': 3, 'action_type': 'discrete'}, 'accelerate_sideways': {'size': 3, 'action_type': 'discrete'}, 'turn': {'size': 3, 'action_type': 'discrete'}, 'shoot': {'size': 2, 'action_type': 'discrete'}}]
# observation space [{'right_eye': {'size': [3, 300, 320], 'space': 'box'}, 'left_eye': {'size': [3, 300, 320], 'space': 'box'}, 'hp': {'size': [1], 'space': 'box'}}, {'right_eye': {'size': [3, 300, 320], 'space': 'box'}, 'left_eye': {'size': [3, 300, 320], 'space': 'box'}, 'hp': {'size': [1], 'space': 'box'}}]
# Environment: GodotEnv
# Action space: Tuple(Discrete(3), Discrete(3), Discrete(2), Discrete(3))
# Observation space: Dict('hp': Box(-1.0, 1.0, (1,), float32), 'left_eye': Box(-1.0, 1.0, (3, 300, 320), float32), 'right_eye': Box(-1.0, 1.0, (3, 300, 320), float32))
# envs:2

# %%
# Test observation structure
obs, _ = env.reset()
print(f"Number of agents: {len(obs)}")
print(f"Agent 0 observation keys: {obs[0].keys()}")

# Decode and check image shapes
right_eye_hex = obs[0]['right_eye']
right_eye_bytes = bytes.fromhex(right_eye_hex)
right_eye_arr = np.frombuffer(right_eye_bytes, dtype=np.uint8)
print(f"Right eye raw data length: {len(right_eye_arr)}")

left_eye_hex = obs[0]['left_eye']
left_eye_bytes = bytes.fromhex(left_eye_hex)
left_eye_arr = np.frombuffer(left_eye_bytes, dtype=np.uint8)
print(f"Left eye raw data length: {len(left_eye_arr)}")

hp = obs[0]['hp']
print(f"HP: {hp}")


print(f"Number of agents: {len(obs)}")
print(f"Agent 0 observation keys: {obs[1].keys()}")

# Decode and check image shapes
right_eye_hex = obs[1]['right_eye']
right_eye_bytes = bytes.fromhex(right_eye_hex)
right_eye_arr = np.frombuffer(right_eye_bytes, dtype=np.uint8)
print(f"Right eye raw data length: {len(right_eye_arr)}")

left_eye_hex = obs[1]['left_eye']
left_eye_bytes = bytes.fromhex(left_eye_hex)
left_eye_arr = np.frombuffer(left_eye_bytes, dtype=np.uint8)
print(f"Left eye raw data length: {len(left_eye_arr)}")

hp = obs[1]['hp']
print(f"HP2: {hp}")
# Out:
# Number of agents: 2
# Agent 0 observation keys: dict_keys(['right_eye', 'left_eye', 'hp'])
# Right eye raw data length: 288000
# Left eye raw data length: 288000
# HP: [6]
# Number of agents: 2
# Agent 0 observation keys: dict_keys(['right_eye', 'left_eye', 'hp'])
# Right eye raw data length: 288000
# Left eye raw data length: 288000
# HP2: [6]

# %%
# GodotEnv Preprocessor
class GodotPreprocessor:
    """Preprocesses GodotEnv observations.
    
    Combines:
    - left_eye (320 width, 300 height) and right_eye (320 width, 300 height) images
    - Previous output (out_next) from model
    - Current HP
    
    Process:
    - Stack left_eye and right_eye vertically: (3, 600, 320)
    - HP embedded as (3, 40, 320)
    - Combined observation: (3, 640, 320)
    - Concatenate with out_next (3, 640, 320) horizontally: (3, 640, 640)
    
    Final input shape: (3, 640, 640)
    """
    
    def __init__(self):
        self.original_eye_size = (300, 320)  # (height, width) from GodotEnv
        self.hp_height = 40  # Height for HP bar
        self.out_next_shape = (3, 640, 320)  # Shape of model output / previous output
        
    def reset(self):
        """No state to clear."""
        pass
    
    def decode_eye(self, eye_hex):
        """Decode hex string to numpy array (H, W, 3)."""
        eye_bytes = bytes.fromhex(eye_hex)
        arr = np.frombuffer(eye_bytes, dtype=np.uint8)
        # Original shape is (height=300, width=320, 3)
        img = arr.reshape(self.original_eye_size[0], self.original_eye_size[1], 3)
        return img
    
    def get_state(self, obs_dict):
        """Process observation dict from a single agent.
        
        Args:
            obs_dict: dict with 'left_eye', 'right_eye', 'hp' keys
            
        Returns:
            combined_eyes: (3, 600, 320) - vertically stacked eyes
            hp: float - health value normalized to [0, 1]
        """
        # Decode eyes - each is (300, 320, 3) = (height, width, channels)
        left_eye = self.decode_eye(obs_dict['left_eye'])  # (300, 320, 3)
        right_eye = self.decode_eye(obs_dict['right_eye'])  # (300, 320, 3)
        
        # Stack vertically without resizing: (600, 320, 3)
        combined = np.concatenate([left_eye, right_eye], axis=0)
        
        # Normalize to [0, 1] and transpose to (3, 600, 320)
        combined = combined.astype(np.float32) / 255.0
        combined = np.transpose(combined, (2, 0, 1))
        
        # Get HP (it's a list with one element, normalize assuming max HP is 100)
        hp_value = obs_dict['hp']
        if isinstance(hp_value, (list, np.ndarray)):
            hp_value = hp_value[0]  # Extract first element from list
        hp = float(hp_value) / 100.0  # Normalize HP
        
        return combined, hp
    
    def combine_state_with_out_next_and_hp(self, combined_eyes, hp, out_next=None):
        """Combine eyes, hp, and out_next into final input.
        
        Args:
            combined_eyes: (3, 600, 320) - vertically stacked eyes
            hp: float - normalized health value
            out_next: (3, 640, 320) or None - previous model output
            
        Returns:
            combined: (3, 640, 640) - full input for model
        """
        _, eye_h, eye_w = combined_eyes.shape  # (3, 600, 320)
        
        # Create HP embedding: broadcast hp value to (3, 40, 320)
        hp_embed = np.full((3, self.hp_height, eye_w), hp, dtype=np.float32)
        
        # Concatenate vertically: eyes (3, 600, 320) + hp (3, 40, 320) = (3, 640, 320)
        current_obs = np.concatenate([combined_eyes, hp_embed], axis=1)
        
        # If out_next is None, create zeros (3, 640, 320)
        if out_next is None:
            out_next = np.zeros(self.out_next_shape, dtype=np.float32)
        
        # Concatenate horizontally: current_obs (3, 640, 320) + out_next (3, 640, 320) = (3, 640, 640)
        combined = np.concatenate([current_obs, out_next], axis=2)
        
        return combined
    
    def get_input_shape(self):
        """Return the expected input shape for the model."""
        return (3, 640, 640)
    
    def get_out_next_shape(self):
        """Return the expected shape of out_next (model output)."""
        return self.out_next_shape  # (3, 640, 320)


# Test the preprocessor
preprocessor = GodotPreprocessor()
combined_eyes, hp = preprocessor.get_state(obs[0])
print(f"Combined eyes shape: {combined_eyes.shape}")  # Should be (3, 600, 320)
print(f"HP value: {hp}")

combined_full = preprocessor.combine_state_with_out_next_and_hp(combined_eyes, hp)
print(f"Full combined shape (with zeros out_next): {combined_full.shape}")  # Should be (3, 640, 640)
print(f"Expected input shape: {preprocessor.get_input_shape()}")  # (3, 640, 640)
print(f"Expected out_next shape: {preprocessor.get_out_next_shape()}")  # (3, 640, 320)
# Out:
# Combined eyes shape: (3, 600, 320)
# HP value: 0.06
# Full combined shape (with zeros out_next): (3, 640, 640)
# Expected input shape: (3, 640, 640)
# Expected out_next shape: (3, 640, 320)

# %%
from torchvision.models import mobilenet_v3_small, MobileNet_V3_Small_Weights

# Action dimensions for GodotEnv
ACTION_DIMS = {
    'accelerate_forward': 3,
    'accelerate_sideways': 3,
    'turn': 3,
    'shoot': 2
}
TOTAL_ACTIONS = sum(ACTION_DIMS.values())  # 3 + 3 + 3 + 2 = 11


class MobileNetV3PolicyGodot(nn.Module):
    """MobileNetV3-based policy for GodotEnv with multi-discrete actions.
    
    Input: (3, 640, 640) - combined (eyes + hp) + out_next
    Output: (3, 640, 320) - used for action selection and as out_next for next step
    
    Action space: Multi-discrete
    - accelerate_forward: 3 choices
    - accelerate_sideways: 3 choices  
    - turn: 3 choices
    - shoot: 2 choices
    """
    
    def __init__(self, pretrained=True, freeze_backbone=False):
        super(MobileNetV3PolicyGodot, self).__init__()
        self.action_dims = ACTION_DIMS
        self.total_actions = TOTAL_ACTIONS
        self.out_h = 640  # Output height
        self.out_w = 320  # Output width
        
        # Load pretrained MobileNetV3-Small
        if pretrained:
            weights = MobileNet_V3_Small_Weights.IMAGENET1K_V1
            backbone = mobilenet_v3_small(weights=weights)
        else:
            backbone = mobilenet_v3_small(weights=None)
        
        # Keep only the feature extractor
        # Input: (batch, 3, 640, 640)
        # MobileNetV3-Small features output: (batch, 576, H/32, W/32)
        # For 640x640 input: output is (batch, 576, 20, 20)
        self.features = backbone.features
        
        if freeze_backbone:
            for param in self.features.parameters():
                param.requires_grad = False
        
        # Upsample to output shape (3, 640, 320)
        self.upsample_conv1 = nn.Sequential(
            nn.Conv2d(576, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
        )
        self.upsample_conv2 = nn.Sequential(
            nn.Conv2d(256, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
        )
        self.upsample_conv3 = nn.Conv2d(64, 3, kernel_size=3, padding=1)
        
        self._init_upsample_weights()
    
    def _init_upsample_weights(self):
        for m in [self.upsample_conv1, self.upsample_conv2, self.upsample_conv3]:
            for layer in m.modules() if isinstance(m, nn.Sequential) else [m]:
                if isinstance(layer, nn.Conv2d):
                    nn.init.orthogonal_(layer.weight, gain=np.sqrt(2))
                    if layer.bias is not None:
                        nn.init.zeros_(layer.bias)
    
    def forward(self, x):
        """Forward pass, returns (batch, 3, 640, 320)."""
        # Extract features: (batch, 3, 640, 640) -> (batch, 576, 20, 20)
        features = self.features(x)
        
        # Upsample using interpolate for flexible sizing
        x = self.upsample_conv1(features)  # (batch, 256, 20, 20)
        x = F.interpolate(x, size=(160, 80), mode='bilinear', align_corners=False)
        
        x = self.upsample_conv2(x)  # (batch, 64, 160, 80)
        x = F.interpolate(x, size=(self.out_h, self.out_w), mode='bilinear', align_corners=False)
        
        # Final conv: (batch, 64, 640, 320) -> (batch, 3, 640, 320)
        out = self.upsample_conv3(x)
        return out
    
    def extract_action_logits_from_crops(self, out):
        """Extract logits for each action choice from 11 consecutive 3x8x8 crops.
        
        Args:
            out: tensor (batch, 3, 640, 320) - model output
            
        Returns:
            logits: list of tensors, one per action type with shape (batch, action_size)
        """
        # Extract 11 crops from the first row: each crop is 3x8x8
        # Crop i: out[:, :, 0:8, i*8:(i+1)*8]
        crop_values = []
        for i in range(self.total_actions):
            crop = out[:, :, 0:8, i*8:(i+1)*8]  # (batch, 3, 8, 8)
            crop_mean = crop.mean(dim=(1, 2, 3))  # (batch,) - mean across channels and spatial dims
            crop_values.append(crop_mean)
        
        # Stack all crop values: (batch, 11)
        all_logits = torch.stack(crop_values, dim=1)  # (batch, 11)
        
        # Split into action-specific logits
        logits = []
        idx = 0
        for action_name, action_size in self.action_dims.items():
            action_logits = all_logits[:, idx:idx + action_size]  # (batch, action_size)
            logits.append(action_logits)
            idx += action_size
        
        return logits
    
    def act(self, combined_state):
        """Select actions and generate out_next for next step.
        
        Args:
            combined_state: (3, 640, 640) - combined (eyes + hp) + out_next
            
        Returns:
            actions: dict with action keys
            log_prob: tensor - sum of log probabilities
            out_next: numpy array (3, 640, 320) - output for next step's input
        """
        if len(combined_state.shape) == 3:
            combined_state = combined_state[np.newaxis, ...]
        
        state_tensor = torch.FloatTensor(combined_state).to(device)
        out = self.forward(state_tensor)  # (1, 3, 640, 320)
        
        # Extract action logits from first 11 3x8x8 crops
        action_logits_list = self.extract_action_logits_from_crops(out)
        
        # Select actions for each action dimension
        actions = {}
        log_probs = []
        
        for (action_name, action_size), action_logits in zip(self.action_dims.items(), action_logits_list):
            probs = F.softmax(action_logits, dim=1).cpu()
            
            m = Categorical(probs)
            action = m.sample()
            log_prob = m.log_prob(action)
            
            actions[action_name] = action.item()
            log_probs.append(log_prob)
        
        # Sum log probs for total action probability
        total_log_prob = torch.stack(log_probs).sum()
        
        # out_next is directly the model output (3, 640, 320)
        out_next = out.squeeze(0).detach().cpu().numpy()  # (3, 640, 320)
        
        return actions, total_log_prob, out_next


# Create and test the model
policy = MobileNetV3PolicyGodot(pretrained=True, freeze_backbone=False).to(device)
print(f"MobileNetV3 Policy for GodotEnv:")
print(policy)

# Count parameters
total_params = sum(p.numel() for p in policy.parameters())
trainable_params = sum(p.numel() for p in policy.parameters() if p.requires_grad)
print(f"\nTotal parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")

# Test forward pass with correct input size
test_input = torch.randn(1, 3, 640, 640).to(device)
test_output = policy(test_input)
print(f"\nTest input shape: {test_input.shape}")  # (1, 3, 640, 640)
print(f"Test output shape: {test_output.shape}")  # (1, 3, 640, 320)
# Out:
# MobileNetV3 Policy for GodotEnv:
# MobileNetV3PolicyGodot(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(88, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(96, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 144, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): Conv2dNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (upsample_conv1): Sequential(
#     (0): Conv2d(576, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (upsample_conv2): Sequential(
#     (0): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (upsample_conv3): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
#
# Total parameters: 2,403,619
# Trainable parameters: 2,403,619
#
# Test input shape: torch.Size([1, 3, 640, 640])
# Test output shape: torch.Size([1, 3, 640, 320])

# %%
# Test the act function
combined_eyes, hp = preprocessor.get_state(obs[0])
combined_full = preprocessor.combine_state_with_out_next_and_hp(combined_eyes, hp)
print(f"Combined eyes shape: {combined_eyes.shape}")  # Should be (3, 600, 320)
print(f"Input shape: {combined_full.shape}")  # Should be (3, 640, 640)

actions, log_prob, out_next = policy.act(combined_full)
print(f"Actions: {actions}")
print(f"Log prob: {log_prob}")
print(f"Out next shape: {out_next.shape}")  # Should be (3, 640, 320)

# Test with out_next feedback
combined_full_with_out_next = preprocessor.combine_state_with_out_next_and_hp(combined_eyes, hp, out_next)
print(f"Input with out_next shape: {combined_full_with_out_next.shape}")  # Should be (3, 640, 640)
# Out:
# Combined eyes shape: (3, 600, 320)
# Input shape: (3, 640, 640)
# Actions: {'accelerate_forward': 1, 'accelerate_sideways': 2, 'turn': 1, 'shoot': 1}
# Log prob: -3.8690590858459473
# Out next shape: (3, 640, 320)
# Input with out_next shape: (3, 640, 640)

# %%
# Multi-Agent Policy Manager for parallel training with independent models
class MultiAgentPolicyManager:
    """Manages multiple independent policy instances for evolutionary-style training.
    
    Each agent has:
    - Independent policy model with separate parameters
    - Independent optimizer
    - Independent preprocessor state
    - Cached parameters for death penalty
    - Out_next state for recurrent-like behavior
    - Survival time tracking (fitness metric)
    """
    
    def __init__(self, n_agents, device, pretrained=True, freeze_backbone=False, lr_max=1e-4):
        self.n_agents = n_agents
        self.device = device
        
        # Create independent components for each agent
        self.policies = []
        self.optimizers = []
        self.preprocessors = []
        
        # Per-agent state
        self.cached_params = [None] * n_agents
        self.cached_state_tensors = [None] * n_agents
        self.out_nexts = [None] * n_agents
        
        # Fitness tracking (survival time)
        self.current_survival_times = [0] * n_agents  # Current episode survival
        self.total_survival_times = [0] * n_agents    # Accumulated across all episodes
        self.death_counts = [0] * n_agents            # Number of deaths per agent
        self.survival_history = [[] for _ in range(n_agents)]  # History of survival times
        
        print(f"Creating {n_agents} independent policy instances...")
        for i in range(n_agents):
            # Create independent policy
            policy = MobileNetV3PolicyGodot(pretrained=pretrained, freeze_backbone=freeze_backbone).to(device)
            optimizer = optim.Adam(policy.parameters(), lr=lr_max)
            preprocessor = GodotPreprocessor()
            
            self.policies.append(policy)
            self.optimizers.append(optimizer)
            self.preprocessors.append(preprocessor)
        
        # Calculate total parameters
        total_params = sum(p.numel() for p in self.policies[0].parameters()) * n_agents
        print(f"Total parameters across all agents: {total_params:,}")
        print(f"Memory estimate: ~{total_params * 4 / 1024 / 1024:.1f} MB")
    
    def reset_all_states(self):
        """Reset all agent states (call at episode start)."""
        for i in range(self.n_agents):
            self.preprocessors[i].reset()
            self.out_nexts[i] = None
            self.current_survival_times[i] = 0
    
    def reset_agent_state(self, agent_idx):
        """Reset state for a single agent (call after death)."""
        self.preprocessors[agent_idx].reset()
        self.out_nexts[agent_idx] = None
        # Record survival time before reset
        if self.current_survival_times[agent_idx] > 0:
            self.survival_history[agent_idx].append(self.current_survival_times[agent_idx])
            self.total_survival_times[agent_idx] += self.current_survival_times[agent_idx]
            self.death_counts[agent_idx] += 1
        self.current_survival_times[agent_idx] = 0
    
    def cache_params(self, agent_idx, state_tensor):
        """Cache parameters for a single agent."""
        self.cached_params[agent_idx] = {
            k: v.clone() for k, v in self.policies[agent_idx].state_dict().items()
        }
        self.cached_state_tensors[agent_idx] = state_tensor.clone()
    
    def get_fitness_stats(self):
        """Get fitness statistics for all agents."""
        stats = []
        for i in range(self.n_agents):
            avg_survival = np.mean(self.survival_history[i]) if self.survival_history[i] else 0
            stats.append({
                'agent_idx': i,
                'total_survival': self.total_survival_times[i],
                'death_count': self.death_counts[i],
                'avg_survival': avg_survival,
                'current_survival': self.current_survival_times[i],
            })
        return stats
    
    def print_fitness_ranking(self):
        """Print fitness ranking of all agents."""
        stats = self.get_fitness_stats()
        # Sort by average survival time (descending)
        sorted_stats = sorted(stats, key=lambda x: x['avg_survival'], reverse=True)
        
        print("\n=== Agent Fitness Ranking (by avg survival time) ===")
        for rank, s in enumerate(sorted_stats):
            print(f"  #{rank+1} Agent {s['agent_idx']}: "
                  f"avg={s['avg_survival']:.1f} steps, "
                  f"total={s['total_survival']}, "
                  f"deaths={s['death_count']}, "
                  f"current={s['current_survival']}")
        print("=" * 50)
        return sorted_stats
    
    def get_best_agent_idx(self):
        """Get the index of the best performing agent (by avg survival)."""
        stats = self.get_fitness_stats()
        best_idx = max(range(self.n_agents), 
                       key=lambda i: stats[i]['avg_survival'] if stats[i]['death_count'] > 0 else stats[i]['current_survival'])
        return best_idx
    
    def save_best_agent(self, path="my_best_godot_policy.pth"):
        """Save the best performing agent's model."""
        best_idx = self.get_best_agent_idx()
        torch.save(self.policies[best_idx].state_dict(), path)
        print(f"Saved best agent (Agent {best_idx}) to {path}")
        return best_idx
    
    def save_all_agents(self, path_prefix="saved_models/agent"):
        """Save all agents' models."""
        for i in range(self.n_agents):
            path = f"{path_prefix}_{i}.pth"
            torch.save(self.policies[i].state_dict(), path)
        print(f"Saved all {self.n_agents} agents to {path_prefix}_*.pth")


# Test the MultiAgentPolicyManager
print("\nTesting MultiAgentPolicyManager...")
test_manager = MultiAgentPolicyManager(n_agents=2, device=device, pretrained=True)
print(f"Created manager with {test_manager.n_agents} agents")
print(f"Policy 0 parameters: {sum(p.numel() for p in test_manager.policies[0].parameters()):,}")
print(f"Policy 1 parameters: {sum(p.numel() for p in test_manager.policies[1].parameters()):,}")
# Out:
# Testing MultiAgentPolicyManager...
# Creating 2 independent policy instances...
# Total parameters across all agents: 4,807,238
# Memory estimate: ~18.3 MB
# Created manager with 2 agents
# Policy 0 parameters: 2,403,619
# Policy 1 parameters: 2,403,619

# %%
def extract_loss_and_lr_regions(out_next):
    """
    Extract the middle 3x8x8 region (LOSS region) and adjacent region (LR region) from model output.
    
    Model output shape: (3, 640, 320)
    LOSS region: center 3x8x8 - used for computing loss
    LR region: adjacent 3x8x8 to the right - used for determining learning rate
    
    Args:
        out_next: numpy array (3, 640, 320)
        
    Returns:
        loss_region: (3, 8, 8) - center region for loss
        lr_region: (3, 8, 8) - adjacent region for learning rate
    """
    # Model output is (3, 640, 320)
    # Center: height 640/2=320, width 320/2=160
    # LOSS region: [316:324, 156:164] (8x8 centered)
    h_center = 320
    w_center = 160
    half_size = 4
    
    loss_region = out_next[:, h_center-half_size:h_center+half_size, w_center-half_size:w_center+half_size]
    # LR region: adjacent to the right [316:324, 164:172]
    lr_region = out_next[:, h_center-half_size:h_center+half_size, w_center+half_size:w_center+half_size*2]
    
    return loss_region, lr_region


def compute_loss_from_region(loss_region):
    """
    Compute loss value from the LOSS region (3x8x8).
    Uses mean squared error from target (zero) plus variance to encourage diversity.
    
    Args:
        loss_region: torch tensor (3, 8, 8)
        
    Returns:
        loss: scalar tensor
    """
    # Use mean of absolute values as loss (encourage outputs to be non-zero but controlled)
    # Add variance term to encourage diverse outputs
    mean_abs = torch.abs(loss_region).mean()
    variance = loss_region.var()
    
    # Loss = mean absolute value - small variance bonus (encourage diversity)
    loss = mean_abs - 0.1 * variance
    return loss


def compute_lr_from_region(lr_region, lr_min=1e-6, lr_max=1e-4):
    """
    Compute learning rate from the LR region (3x8x8) normalized.
    
    Args:
        lr_region: numpy array (3, 8, 8)
        lr_min: minimum learning rate
        lr_max: maximum learning rate
        
    Returns:
        lr: float - learning rate in [lr_min, lr_max]
    """
    # Normalize the region to [0, 1] using sigmoid-like function
    lr_mean = np.mean(lr_region)
    # Use tanh to bound the value, then scale to [0, 1]
    normalized = (np.tanh(lr_mean) + 1) / 2  # Maps to [0, 1]
    
    # Scale to learning rate range
    lr = lr_min + normalized * (lr_max - lr_min)
    return float(lr)


def reinforce_godot(policy, optimizer, preprocessor, env, n_training_episodes, max_t, gamma, print_every, 
                   lr_min=1e-6, lr_max=1e-4, cache_every=20, death_lr=1e-2, n_agents=8):
    """
    REINFORCE algorithm for GodotEnv with per-step updates.
    
    Key changes:
    1. Update parameters after every step (not mini-batches)
    2. Use middle 3x8x8 region from model output as loss
    3. Learning rate determined by adjacent 3x8x8 region
    4. Cache parameters every 20 steps
    5. When HP <= 0: compute negative loss gradient and apply to cached params with large LR
    
    Note: GodotEnv supports multiple agents. We train on agent 0 for simplicity.
    """
    scores_deque = deque(maxlen=100)
    scores = []
    best_score = -np.inf
    
    # Parameter cache (stores state_dict copy)
    cached_params = None
    # Also cache the state tensor for death update
    cached_state_tensor = None
    
    for i_episode in range(1, n_training_episodes + 1):
        # Reset environment and preprocessor
        obs, _ = env.reset()
        preprocessor.reset()

        # Get initial state for agent 0
        combined_eyes, hp = preprocessor.get_state(obs[0])
        
        # Initialize out_next as None (will be zeros on first step)
        out_next = None
        
        # Track total episode reward
        episode_reward = 0
        total_steps = 0
        done = False
        
        for t in range(max_t):
            # Combine state with out_next and hp
            combined_state = preprocessor.combine_state_with_out_next_and_hp(
                combined_eyes, hp, out_next
            )
            
            # Forward pass to get output tensor (need gradients for loss)
            if len(combined_state.shape) == 3:
                state_batch = combined_state[np.newaxis, ...]
            else:
                state_batch = combined_state
            state_tensor = torch.FloatTensor(state_batch).to(device)
            
            # Get model output with gradients
            model_output = policy(state_tensor)  # (1, 3, 640, 320)
            
            # Extract LOSS and LR regions
            out_numpy = model_output.squeeze(0).detach().cpu().numpy()  # (3, 640, 320)
            loss_region_np, lr_region_np = extract_loss_and_lr_regions(out_numpy)
            
            # Compute dynamic learning rate from LR region
            dynamic_lr = compute_lr_from_region(lr_region_np, lr_min, lr_max)
            
            # Update optimizer learning rate
            for param_group in optimizer.param_groups:
                param_group['lr'] = dynamic_lr
            
            # Compute loss from LOSS region (need tensor version for backprop)
            loss_region_tensor = model_output[:, :, 316:324, 156:164]  # (1, 3, 8, 8)
            loss = compute_loss_from_region(loss_region_tensor.squeeze(0))
            
            # === Per-step parameter update ===
            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(policy.parameters(), max_norm=0.5)
            optimizer.step()
            
            # Get actions from the output using 3x8x8 crops (using detached output)
            action_logits_list = policy.extract_action_logits_from_crops(model_output.detach())
            actions = {}
            for (action_name, action_size), action_logits in zip(policy.action_dims.items(), action_logits_list):
                probs = F.softmax(action_logits, dim=1).cpu()
                m = Categorical(probs)
                action = m.sample()
                actions[action_name] = action.item()
            
            # out_next for next step's input
            out_next = out_numpy
            
            # Format actions for all agents (use same actions for all)
            all_actions = []
            for _ in range(n_agents):
                agent_action = [
                    actions['accelerate_forward'],
                    actions['accelerate_sideways'],
                    actions['turn'],
                    actions['shoot']
                ]
                all_actions.append(agent_action)
            
            # Step environment
            obs, reward_list, terminated_list, truncated_list, _ = env.step(all_actions)
            # Get reward for agent 0
            reward = reward_list[0] if isinstance(reward_list, list) else reward_list
            done = (terminated_list[0] if isinstance(terminated_list, list) else terminated_list) or \
                   (truncated_list[0] if isinstance(truncated_list, list) else truncated_list)
            
            episode_reward += reward
            total_steps += 1
            
            # Get next state and HP
            combined_eyes, hp = preprocessor.get_state(obs[0])
            current_hp = hp * 100  # Denormalize HP for comparison
            
            # === Cache parameters every 20 steps ===
            if total_steps % cache_every == 0:
                # Deep copy of current parameters
                cached_params = {k: v.clone() for k, v in policy.state_dict().items()}
                # Also cache the current state tensor for potential death update
                cached_state_tensor = state_tensor.clone()
                if total_steps % (cache_every * 5) == 0:
                    print(f"  [Step {total_steps}] Cached parameters, HP={current_hp:.1f}, LR={dynamic_lr:.2e}")
            
            # === Handle death: apply negative loss gradient to cached params ===
            if current_hp <= 0:
                print(f"  [Step {total_steps}] HP depleted! Applying negative loss update to cached params...")
                
                if cached_params is not None:
                    # Step 1: Load cached parameters into the model
                    policy.load_state_dict(cached_params)
                    
                    # Step 2: Forward pass with current state using cached params
                    model_output_cached = policy(state_tensor)  # (1, 3, 640, 320)
                    
                    # Step 3: Compute loss from LOSS region
                    loss_region_cached = model_output_cached[:, :, 316:324, 156:164]
                    loss_cached = compute_loss_from_region(loss_region_cached.squeeze(0))
                    
                    # Step 4: Negate the loss to create loss2 (reverse gradient direction)
                    loss2 = -loss_cached
                    
                    # Step 5: Compute gradients and apply with larger learning rate
                    optimizer.zero_grad()
                    loss2.backward()
                    torch.nn.utils.clip_grad_norm_(policy.parameters(), max_norm=1.0)
                    
                    # Use larger learning rate for death update
                    for param_group in optimizer.param_groups:
                        param_group['lr'] = death_lr
                    optimizer.step()
                    
                    # Restore normal learning rate range
                    for param_group in optimizer.param_groups:
                        param_group['lr'] = lr_max
                    
                    print(f"    Applied negative loss gradient with death_lr={death_lr:.0e}")
                
                # Reset environment
                obs, _ = env.reset()
                preprocessor.reset()
                combined_eyes, hp = preprocessor.get_state(obs[0])
                out_next = None  # Reset out_next
                
                # Don't break, continue training in new episode
                continue
            
            # === Handle done: reset environment and continue training ===
            if done:
                print(f"  [Step {total_steps}] Episode done! Resetting environment...")
                obs, _ = env.reset()
                preprocessor.reset()
                combined_eyes, hp = preprocessor.get_state(obs[0])
                out_next = None  # Reset out_next
                continue
        
        # Track episode stats
        scores_deque.append(episode_reward)
        scores.append(episode_reward)
        
        # Save best model
        if episode_reward > best_score:
            best_score = episode_reward
            torch.save(policy.state_dict(), "my_best_godot_policy.pth")

        if i_episode % print_every == 0:
            avg_score = np.mean(scores_deque)
            print(f"Episode {i_episode}\tAverage Score: {avg_score:.2f}\tBest: {best_score:.2f}\tSteps: {total_steps}")

    return scores

# %%
def reinforce_godot_multi_agent(manager, env, n_training_episodes, max_t, gamma, print_every, 
                                  lr_min=1e-6, lr_max=1e-4, cache_every=20, death_lr=1e-2):
    """
    Multi-Agent REINFORCE algorithm for GodotEnv with per-step updates.
    
    Each agent has independent:
    - Policy model with separate parameters
    - Optimizer
    - Preprocessor state
    - Cached parameters for death penalty
    
    Key features:
    1. All agents train independently in parallel
    2. Each agent uses its own model output for action selection
    3. Death penalty applied independently to each agent
    4. Survival time tracked as fitness metric
    
    Args:
        manager: MultiAgentPolicyManager instance
        env: GodotEnv instance
        n_training_episodes: number of episodes
        max_t: maximum steps per episode
        gamma: discount factor (unused in per-step updates)
        print_every: print interval
        lr_min: minimum learning rate
        lr_max: maximum learning rate
        cache_every: cache parameters every N steps
        death_lr: learning rate for death penalty update
    
    Returns:
        scores: list of total rewards per episode
    """
    n_agents = manager.n_agents
    scores_deque = deque(maxlen=100)
    scores = []
    best_score = -np.inf
    
    for i_episode in range(1, n_training_episodes + 1):
        # Reset environment
        obs, _ = env.reset()
        
        # Reset all agent states
        manager.reset_all_states()
        
        # Get initial states for all agents
        combined_eyes_list = []
        hp_list = []
        for agent_idx in range(n_agents):
            combined_eyes, hp = manager.preprocessors[agent_idx].get_state(obs[agent_idx])
            combined_eyes_list.append(combined_eyes)
            hp_list.append(hp)
        
        # Track total episode reward (sum across all agents)
        episode_reward = 0
        total_steps = 0
        
        for t in range(max_t):
            all_actions = []
            
            # Process each agent independently
            for agent_idx in range(n_agents):
                policy = manager.policies[agent_idx]
                optimizer = manager.optimizers[agent_idx]
                preprocessor = manager.preprocessors[agent_idx]
                
                # Combine state with out_next and hp
                combined_state = preprocessor.combine_state_with_out_next_and_hp(
                    combined_eyes_list[agent_idx], 
                    hp_list[agent_idx], 
                    manager.out_nexts[agent_idx]
                )
                
                # Forward pass to get output tensor (need gradients for loss)
                if len(combined_state.shape) == 3:
                    state_batch = combined_state[np.newaxis, ...]
                else:
                    state_batch = combined_state
                state_tensor = torch.FloatTensor(state_batch).to(manager.device)
                
                # Get model output with gradients
                model_output = policy(state_tensor)  # (1, 3, 640, 320)
                
                # Extract LOSS and LR regions
                out_numpy = model_output.squeeze(0).detach().cpu().numpy()  # (3, 640, 320)
                loss_region_np, lr_region_np = extract_loss_and_lr_regions(out_numpy)
                
                # Compute dynamic learning rate from LR region
                dynamic_lr = compute_lr_from_region(lr_region_np, lr_min, lr_max)
                
                # Update optimizer learning rate
                for param_group in optimizer.param_groups:
                    param_group['lr'] = dynamic_lr
                
                # Compute loss from LOSS region (need tensor version for backprop)
                loss_region_tensor = model_output[:, :, 316:324, 156:164]  # (1, 3, 8, 8)
                loss = compute_loss_from_region(loss_region_tensor.squeeze(0))
                
                # === Per-step parameter update ===
                optimizer.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(policy.parameters(), max_norm=0.5)
                optimizer.step()
                
                # Get actions from the output using 3x8x8 crops (using detached output)
                action_logits_list = policy.extract_action_logits_from_crops(model_output.detach())
                actions = {}
                for (action_name, action_size), action_logits in zip(policy.action_dims.items(), action_logits_list):
                    probs = F.softmax(action_logits, dim=1).cpu()
                    m = Categorical(probs)
                    action = m.sample()
                    actions[action_name] = action.item()
                
                # Update out_next for next step
                manager.out_nexts[agent_idx] = out_numpy
                
                # Format action for this agent
                agent_action = [
                    actions['accelerate_forward'],
                    actions['accelerate_sideways'],
                    actions['turn'],
                    actions['shoot']
                ]
                all_actions.append(agent_action)
                
                # === Cache parameters every N steps ===
                if total_steps % cache_every == 0:
                    manager.cache_params(agent_idx, state_tensor)
            
            # Step environment with all agent actions
            obs, reward_list, terminated_list, truncated_list, _ = env.step(all_actions, True)
            
            # Process results for each agent
            total_reward_this_step = 0
            for agent_idx in range(n_agents):
                # Get reward for this agent
                reward = reward_list[agent_idx] if isinstance(reward_list, list) else reward_list
                total_reward_this_step += reward
                
                # Get next state and HP for this agent
                combined_eyes, hp = manager.preprocessors[agent_idx].get_state(obs[agent_idx])
                combined_eyes_list[agent_idx] = combined_eyes
                hp_list[agent_idx] = hp
                current_hp = hp * 100  # Denormalize HP
                
                # Update survival time
                if current_hp > 0:
                    manager.current_survival_times[agent_idx] += 1
                
                # === Handle death: apply negative loss gradient to cached params ===
                if current_hp <= 0 and manager.cached_params[agent_idx] is not None:
                    policy = manager.policies[agent_idx]
                    optimizer = manager.optimizers[agent_idx]
                    
                    # Load cached parameters
                    policy.load_state_dict(manager.cached_params[agent_idx])
                    
                    # Get current state tensor
                    combined_state = manager.preprocessors[agent_idx].combine_state_with_out_next_and_hp(
                        combined_eyes, hp, manager.out_nexts[agent_idx]
                    )
                    if len(combined_state.shape) == 3:
                        state_batch = combined_state[np.newaxis, ...]
                    else:
                        state_batch = combined_state
                    state_tensor = torch.FloatTensor(state_batch).to(manager.device)
                    
                    # Forward pass with cached params
                    model_output_cached = policy(state_tensor)
                    
                    # Compute loss from LOSS region
                    loss_region_cached = model_output_cached[:, :, 316:324, 156:164]
                    loss_cached = compute_loss_from_region(loss_region_cached.squeeze(0))
                    
                    # Negate the loss (reverse gradient direction)
                    loss2 = -loss_cached
                    
                    # Compute gradients and apply with larger learning rate
                    optimizer.zero_grad()
                    loss2.backward()
                    torch.nn.utils.clip_grad_norm_(policy.parameters(), max_norm=1.0)
                    
                    # Use larger learning rate for death update
                    for param_group in optimizer.param_groups:
                        param_group['lr'] = death_lr
                    optimizer.step()
                    
                    # Restore normal learning rate
                    for param_group in optimizer.param_groups:
                        param_group['lr'] = lr_max
                    
                    # Reset this agent's state
                    manager.reset_agent_state(agent_idx)
            
            episode_reward += total_reward_this_step
            total_steps += 1
            
            # Print progress periodically
            if total_steps % (cache_every * 5) == 0:
                print(f"  [Step {total_steps}] Agent HP: {[f'{hp:.1f}' for hp in hp_list]}")
            
            # Check if all agents are done (environment reset)
            all_done = all(terminated_list) if isinstance(terminated_list, list) else terminated_list
            if all_done:
                print(f"  [Step {total_steps}] All agents done! Resetting...")
                obs, _ = env.reset()
                manager.reset_all_states()
                for agent_idx in range(n_agents):
                    combined_eyes, hp = manager.preprocessors[agent_idx].get_state(obs[agent_idx])
                    combined_eyes_list[agent_idx] = combined_eyes
                    hp_list[agent_idx] = hp
        
        # Track episode stats
        scores_deque.append(episode_reward)
        scores.append(episode_reward)
        
        # Save best model
        if episode_reward > best_score:
            best_score = episode_reward
            manager.save_best_agent("my_best_godot_policy.pth")
        
        if i_episode % print_every == 0:
            avg_score = np.mean(scores_deque)
            print(f"\nEpisode {i_episode}\tAverage Score: {avg_score:.2f}\tBest: {best_score:.2f}\tSteps: {total_steps}")
            manager.print_fitness_ranking()
    
    return scores

# %%
# Hyperparameters for Multi-Agent GodotEnv training with MobileNetV3
# Updated: each agent has independent model parameters (evolutionary-style)
hyperparameters = {
    "n_training_episodes": 1,
    "n_evaluation_episodes": 1,
    "max_t": 100000,  # Maximum steps per episode
    "gamma": 0.99,
    "lr_min": 1e-5,    # Minimum learning rate (very small)
    "lr_max": 4e-4,    # Maximum learning rate (smaller range)
    "death_lr": 1e-2,  # Large learning rate for death penalty update
    "pretrained": True,
    "freeze_backbone": False,
    "cache_every": 20,  # Cache parameters every 20 steps
    "n_agents": 2,      # Number of agents in GodotEnv (each with independent model)
}

# Create MultiAgentPolicyManager with independent models for each agent
agent_manager = MultiAgentPolicyManager(
    n_agents=hyperparameters["n_agents"],
    device=device,
    pretrained=hyperparameters["pretrained"],
    freeze_backbone=hyperparameters["freeze_backbone"],
    lr_max=hyperparameters["lr_max"]
)

print(f"\n{'='*60}")
print(f"Multi-Agent Training on GodotEnv with MobileNetV3 backbone")
print(f"{'='*60}")
print(f"Device: {device}")
print(f"Number of independent agents: {hyperparameters['n_agents']}")
print(f"Pretrained: {hyperparameters['pretrained']}, Freeze backbone: {hyperparameters['freeze_backbone']}")
print(f"Per-step updates with dynamic learning rate: [{hyperparameters['lr_min']:.0e}, {hyperparameters['lr_max']:.0e}]")
print(f"Death penalty: negative loss gradient with death_lr={hyperparameters['death_lr']:.0e}")
print(f"Parameter cache every {hyperparameters['cache_every']} steps")
print(f"Fitness metric: survival time (steps with HP > 0)")
print(f"Hyperparameters: {hyperparameters}")
print(f"{'='*60}\n")

# Train all agents in parallel
scores = reinforce_godot_multi_agent(
    agent_manager,
    env,
    hyperparameters["n_training_episodes"],
    hyperparameters["max_t"],
    hyperparameters["gamma"],
    print_every=10,
    lr_min=hyperparameters["lr_min"],
    lr_max=hyperparameters["lr_max"],
    cache_every=hyperparameters["cache_every"],
    death_lr=hyperparameters["death_lr"],
)

# Save all agent models
agent_manager.save_all_agents("saved_models/agent")
best_idx = agent_manager.save_best_agent("my_best_godot_policy.pth")

print(f"\n{'='*60}")
print("Training complete!")
print(f"Best performing agent: Agent {best_idx}")
agent_manager.print_fitness_ranking()
print(f"{'='*60}")
# Out:
# Creating 2 independent policy instances...
# Total parameters across all agents: 4,807,238
# Memory estimate: ~18.3 MB
#
# ============================================================
# Multi-Agent Training on GodotEnv with MobileNetV3 backbone
# ============================================================
# Device: mps
# Number of independent agents: 2
# Pretrained: True, Freeze backbone: False
# Per-step updates with dynamic learning rate: [1e-05, 4e-04]
# Death penalty: negative loss gradient with death_lr=1e-02
# Parameter cache every 20 steps
# Fitness metric: survival time (steps with HP > 0)
# Hyperparameters: {'n_training_episodes': 1, 'n_evaluation_episodes': 1, 'max_t': 100000, 'gamma': 0.99, 'lr_min': 1e-05, 'lr_max': 0.0004, 'death_lr': 0.01, 'pretrained': True, 'freeze_backbone': False, 'cache_every': 20, 'n_agents': 2}
# ============================================================
#
#   [Step 100] Total reward: 0.0
#   [Step 200] Total reward: 0.0
#   [Step 300] Total reward: 0.0
#   [Step 400] Total reward: 0.0
#   [Step 500] Total reward: 0.0
#   [Step 600] Total reward: 0.0
#   [Step 700] Total reward: 0.0
#   [Step 800] Total reward: 0.0
#   [Step 900] Total reward: 0.0
#   [Step 1000] Total reward: 0.0
#   [Step 1100] Total reward: 0.0
#   [Step 1200] Total reward: 0.0
#   [Step 1300] Total reward: 0.0
#   [Step 1400] Total reward: 0.0
#   [Step 1500] Total reward: 0.0
#   [Step 1600] Total reward: 0.0
#   [Step 1700] Total reward: 0.0
#   [Step 1800] Total reward: 0.0
#   [Step 1900] Total reward: 0.0
#   [Step 2000] Total reward: 0.0
#   [Step 2100] Total reward: 0.0
#   [Step 2200] Total reward: 0.0
#   [Step 2300] Total reward: 0.0
#   [Step 2400] Total reward: 0.0
#   [Step 2500] Total reward: 0.0
#   [Step 2600] Total reward: 0.0
#   [Step 2700] Total reward: 0.0
#   [Step 2800] Total reward: 0.0
#   [Step 2900] Total reward: 0.0
#   [Step 3000] Total reward: 0.0
#   [Step 3100] Total reward: 0.0
#   [Step 3200] Total reward: 0.0
#   [Step 3300] Total reward: 0.0
#   [Step 3400] Total reward: 0.0
#   [Step 3500] Total reward: 0.0
#   [Step 3600] Total reward: 0.0
#   [Step 3700] Total reward: 0.0
#   [Step 3800] Total reward: 0.0
#   [Step 3900] Total reward: 0.0
#   [Step 4000] Total reward: 0.0
#   [Step 4100] Total reward: 0.0
#   [Step 4200] Total reward: 0.0
#   [Step 4300] Total reward: 0.0
#   [Step 4400] Total reward: 0.0
#   [Step 4500] Total reward: 0.0
#   [Step 4600] Total reward: 0.0
#   [Step 4700] Total reward: 0.0
#   [Step 4800] Total reward: 0.0
#   [Step 4900] Total reward: 0.0
#   [Step 5000] Total reward: 0.0
#   [Step 5100] Total reward: 0.0
#   [Step 5200] Total reward: 2.0
#   [Step 5300] Total reward: 2.0
#   [Step 5400] Total reward: 2.0
#   [Step 5500] Total reward: 2.0
#   [Step 5600] Total reward: 2.0
#   [Step 5700] Total reward: 2.0
#   [Step 5800] Total reward: 2.0
#   [Step 5900] Total reward: 2.0
#   [Step 6000] Total reward: 2.0
#   [Step 6100] Total reward: 2.0
#   [Step 6200] Total reward: 3.0
#   [Step 6300] Total reward: 3.0
#   [Step 6400] Total reward: 3.0
#   [Step 6500] Total reward: 3.0
#   [Step 6600] Total reward: 3.0
#   [Step 6700] Total reward: 3.0
#   [Step 6800] Total reward: 3.0
#   [Step 6900] Total reward: 3.0
#   [Step 7000] Total reward: 4.0
#   [Step 7100] Total reward: 5.0
#   [Step 7200] Total reward: 5.0
#   [Step 7300] Total reward: 5.0
#   [Step 7400] Total reward: 5.0
#   [Step 7500] Total reward: 5.0
#   [Step 7600] Total reward: 5.0
#   [Step 7700] Total reward: 5.0
#   [Step 7800] Total reward: 5.0
#   [Step 7900] Total reward: 5.0
#   [Step 8000] Total reward: 5.0
#   [Step 8100] Total reward: 5.0
#   [Step 8200] Total reward: 5.0
#   [Step 8300] Total reward: 5.0
#   [Step 8400] Total reward: 5.0
#   [Step 8500] Total reward: 5.0
#   [Step 8600] Total reward: 5.0
#   [Step 8700] Total reward: 5.0
#   [Step 8800] Total reward: 5.0
#   [Step 8900] Total reward: 5.0
#   [Step 9000] Total reward: 5.0
#   [Step 9100] Total reward: 5.0
#   [Step 9200] Total reward: 5.0
#   [Step 9300] Total reward: 5.0
#   [Step 9400] Total reward: 5.0
#   [Step 9500] Total reward: 5.0
#   [Step 9600] Total reward: 5.0
#   [Step 9700] Total reward: 5.0
#   [Step 9800] Total reward: 5.0
#   [Step 9900] Total reward: 5.0
#   [Step 10000] Total reward: 5.0
#   [Step 10100] Total reward: 5.0
#   [Step 10200] Total reward: 5.0
#   [Step 10300] Total reward: 5.0
#   [Step 10400] Total reward: 5.0
#   [Step 10500] Total reward: 5.0
#   [Step 10600] Total reward: 5.0
#   [Step 10700] Total reward: 5.0
#   [Step 10800] Total reward: 5.0
#   [Step 10900] Total reward: 5.0
#   [Step 11000] Total reward: 5.0
#   [Step 11100] Total reward: 5.0
#   [Step 11200] Total reward: 5.0
#   [Step 11300] Total reward: 5.0
#   [Step 11400] Total reward: 5.0
#   [Step 11500] Total reward: 5.0
#   [Step 11600] Total reward: 5.0
#   [Step 11700] Total reward: 5.0
#   [Step 11800] Total reward: 5.0
#   [Step 11900] Total reward: 5.0
#   [Step 12000] Total reward: 5.0
#   [Step 12100] Total reward: 5.0
#   [Step 12200] Total reward: 5.0
#   [Step 12300] Total reward: 5.0
#   [Step 12400] Total reward: 5.0
#   [Step 12500] Total reward: 5.0
#   [Step 12600] Total reward: 5.0
#   [Step 12700] Total reward: 5.0
#   [Step 12800] Total reward: 5.0
#   [Step 12900] Total reward: 5.0
#   [Step 13000] Total reward: 5.0
#   [Step 13100] Total reward: 5.0
#   [Step 13200] Total reward: 5.0
#   [Step 13300] Total reward: 5.0
#   [Step 13400] Total reward: 5.0
#   [Step 13500] Total reward: 5.0
#   [Step 13600] Total reward: 5.0
#   [Step 13700] Total reward: 5.0
#   [Step 13800] Total reward: 5.0
#   [Step 13900] Total reward: 5.0
#   [Step 14000] Total reward: 5.0
#   [Step 14100] Total reward: 5.0
#   [Step 14200] Total reward: 5.0
#   [Step 14300] Total reward: 5.0
#   [Step 14400] Total reward: 5.0
#   [Step 14500] Total reward: 5.0
#   [Step 14600] Total reward: 5.0
#   [Step 14700] Total reward: 5.0
#   [Step 14800] Total reward: 5.0
#   [Step 14900] Total reward: 5.0
#   [Step 15000] Total reward: 5.0
#   [Step 15100] Total reward: 5.0
#   [Step 15200] Total reward: 5.0
#   [Step 15300] Total reward: 5.0
#   [Step 15400] Total reward: 6.0
#   [Step 15500] Total reward: 6.0
#   [Step 15600] Total reward: 6.0
#   [Step 15700] Total reward: 6.0
#   [Step 15800] Total reward: 6.0
#   [Step 15900] Total reward: 6.0
#   [Step 16000] Total reward: 6.0
#   [Step 16100] Total reward: 6.0
#   [Step 16200] Total reward: 6.0
#   [Step 16300] Total reward: 6.0
#   [Step 16400] Total reward: 6.0
#   [Step 16500] Total reward: 6.0
#   [Step 16600] Total reward: 6.0
#   [Step 16700] Total reward: 6.0
#   [Step 16800] Total reward: 6.0
#   [Step 16900] Total reward: 6.0
#   [Step 17000] Total reward: 6.0
#   [Step 17100] Total reward: 6.0
#   [Step 17200] Total reward: 6.0
#   [Step 17300] Total reward: 6.0
#   [Step 17400] Total reward: 6.0
#   [Step 17500] Total reward: 6.0
#   [Step 17600] Total reward: 6.0
#   [Step 17700] Total reward: 6.0
#   [Step 17800] Total reward: 6.0
#   [Step 17900] Total reward: 6.0
#   [Step 18000] Total reward: 6.0
#   [Step 18100] Total reward: 6.0
#   [Step 18200] Total reward: 6.0
#   [Step 18300] Total reward: 6.0
#   [Step 18400] Total reward: 6.0
#   [Step 18500] Total reward: 6.0
#   [Step 18600] Total reward: 6.0
#   [Step 18700] Total reward: 6.0
#   [Step 18800] Total reward: 6.0
#   [Step 18900] Total reward: 6.0
#   [Step 19000] Total reward: 6.0
#   [Step 19100] Total reward: 6.0
#   [Step 19200] Total reward: 6.0
#   [Step 19300] Total reward: 6.0
#   [Step 19400] Total reward: 6.0
#   [Step 19500] Total reward: 6.0
#   [Step 19600] Total reward: 6.0
#   [Step 19700] Total reward: 6.0
#   [Step 19800] Total reward: 6.0
#   [Step 19900] Total reward: 6.0
#   [Step 20000] Total reward: 6.0
#   [Step 20100] Total reward: 6.0
#   [Step 20200] Total reward: 6.0
#   [Step 20300] Total reward: 6.0
#   [Step 20400] Total reward: 6.0
#   [Step 20500] Total reward: 6.0
#   [Step 20600] Total reward: 6.0
#   [Step 20700] Total reward: 6.0
#   [Step 20800] Total reward: 6.0
#   [Step 20900] Total reward: 6.0
#   [Step 21000] Total reward: 6.0
#   [Step 21100] Total reward: 6.0
#   [Step 21200] Total reward: 6.0
#   [Step 21300] Total reward: 6.0
#   [Step 21400] Total reward: 6.0
#   [Step 21500] Total reward: 6.0
#   [Step 21600] Total reward: 6.0
#   [Step 21700] Total reward: 6.0
#   [Step 21800] Total reward: 6.0
#   [Step 21900] Total reward: 6.0
#   [Step 22000] Total reward: 6.0
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# Cell In[66], line 40
#      37 print(f"{'='*60}\n")
#      39 # Train all agents in parallel
# ---> 40 scores = reinforce_godot_multi_agent(
#      41     agent_manager,
#      42     env,
#      43     hyperparameters["n_training_episodes"],
#      44     hyperparameters["max_t"],
#      45     hyperparameters["gamma"],
#      46     print_every=10,
#      47     lr_min=hyperparameters["lr_min"],
#      48     lr_max=hyperparameters["lr_max"],
#      49     cache_every=hyperparameters["cache_every"],
#      50     death_lr=hyperparameters["death_lr"],
#      51 )
#      53 # Save all agent models
#      54 agent_manager.save_all_agents("saved_models/agent")
#
# Cell In[65], line 130, in reinforce_godot_multi_agent(manager, env, n_training_episodes, max_t, gamma, print_every, lr_min, lr_max, cache_every, death_lr)
#     127         manager.cache_params(agent_idx, state_tensor)
#     129 # Step environment with all agent actions
# --> 130 obs, reward_list, terminated_list, truncated_list, _ = env.step(all_actions, True)
#     132 # Process results for each agent
#     133 total_reward_this_step = 0
#
# File ~/miniconda3/envs/envolution/lib/python3.10/site-packages/godot_rl/core/godot_env.py:186, in GodotEnv.step(self, action, order_ij)
#     175 """
#     176 Perform one step in the environment.
#     177
#    (...)
#     183     tuple: Tuple containing observation, reward, done flag, termination flag, and info.
#     184 """
#     185 self.step_send(action, order_ij=order_ij)
# --> 186 return self.step_recv()
#
# File ~/miniconda3/envs/envolution/lib/python3.10/site-packages/godot_rl/core/godot_env.py:211, in GodotEnv.step_recv(self)
#     204 def step_recv(self):
#     205     """
#     206     Receive the step response from the Godot environment.
#     207
#     208     Returns:
#     209         tuple: Tuple containing observation, reward, done flag, termination flag, and info.
#     210     """
# --> 211     response = self._get_json_dict()
#     212     response["obs"] = self._process_obs(response["obs"])
#     214     # Kept for backward compatibility if the plugin doesn't send info.
#
# File ~/miniconda3/envs/envolution/lib/python3.10/site-packages/godot_rl/core/godot_env.py:439, in GodotEnv._get_json_dict(self)
#     438 def _get_json_dict(self):
# --> 439     data = self._get_data()
#     440     return json.loads(data)
#
# File ~/miniconda3/envs/envolution/lib/python3.10/site-packages/godot_rl/core/godot_env.py:466, in GodotEnv._get_data(self)
#     463 length: int = 4
#     465 while received_length < length:
# --> 466     data = self.connection.recv(length - received_length)
#     467     received_length += len(data)
#     468     string_size_bytes.extend(data)
#
# ConnectionResetError: [Errno 54] Connection reset by peer

# %%
import matplotlib.pyplot as plt

# Plot training results
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(scores)
plt.xlabel('Episode')
plt.ylabel('Score')
plt.title('Training Scores')

plt.subplot(1, 2, 2)
window = 100
running_avg = np.convolve(scores, np.ones(window)/window, mode='valid')
plt.plot(running_avg)
plt.xlabel('Episode')
plt.ylabel('Running Average Score')
plt.title(f'Running Average ({window} episodes)')

plt.tight_layout()
plt.savefig('godot_training_results.png')
plt.show()

# %%
# Close environment when done
env.close()
print("Environment closed.")
# Out:
# close message sent
# Environment closed.
